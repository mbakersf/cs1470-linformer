# %% [markdown]
# ## IMDB Dataset

# %%
# Setup
# !pip install fairseq

# Download the IMDB dataset
# !wget http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar zxvf aclImdb_v1.tar.gz

# %%
# !pip install fairseq

# %%
# Format data
import os
import random
from glob import glob

def prepare_data(datadir):
    random.seed(0)
    for split in ['train', 'test']:
        samples = []
        for class_label in ['pos', 'neg']:
            fnames = glob(os.path.join(datadir, split, class_label) + '/*.txt')
            for fname in fnames:
                with open(fname, 'r') as fin:
                    line = fin.readline().strip()
                    samples.append((line, 1 if class_label == 'pos' else 0))
        random.shuffle(samples)
        out_fname = 'train' if split == 'train' else 'dev'
        with open(os.path.join(datadir, out_fname + '.input0'), 'w') as f1, \
             open(os.path.join(datadir, out_fname + '.label'), 'w') as f2:
            for sample in samples:
                f1.write(sample[0] + '\n')
                f2.write(str(sample[1]) + '\n')

prepare_data('aclImdb')

# %%
# !git clone https://github.com/pytorch/fairseq
# %cd fairseq
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35184, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 35184 (delta 61), reused 72 (delta 47), pack-reused 35079
# Receiving objects: 100% (35184/35184), 25.22 MiB | 24.71 MiB/s, done.
# Resolving deltas: 100% (25548/25548), done.
# /content/fairseq

# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md  fairseq	   LICENSE	   RELEASE.md	     setup.py
# CONTRIBUTING.md     fairseq_cli    MANIFEST.in	   release_utils.py  tests
# docs		    hubconf.py	   pyproject.toml  scripts	     train.py
# examples	    hydra_plugins  README.md	   setup.cfg

# %%
# Download the BPE encoder and vocabulary
# !wget -N 'https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/encoder.json'
# !wget -N 'https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/vocab.bpe'

# BPE encoding of the data
# !python -m examples.roberta.multiprocessing_bpe_encoder \
    --encoder-json encoder.json \
    --vocab-bpe vocab.bpe \
    --inputs "../aclImdb/train.input0" "../aclImdb/dev.input0" \
    --outputs "../aclImdb/train.input0.bpe" "../aclImdb/dev.input0.bpe" \
    --workers 60 \
    --keep-empty

# %%
# Download the dictionary for fairseq
# !wget -N 'https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt'

# Preprocess the data for fairseq
# !fairseq-preprocess \
    --only-source \
    --trainpref "../aclImdb/train.input0.bpe" \
    --validpref "../aclImdb/dev.input0.bpe" \
    --destdir "../IMDB-bin/input0" \
    --srcdict dict.txt \
    --workers 60

# !fairseq-preprocess \
    --only-source \
    --trainpref "../aclImdb/train.label" \
    --validpref "../aclImdb/dev.label" \
    --destdir "../IMDB-bin/label" \
    --workers 60

# %%
# !pip install tensorboardX

# !fairseq-train "/content/IMDB-bin/" \
    --user-dir /content/fairseq/examples/linformer/linformer_src \
    --max-positions 512 \
    --batch-size 16 \
    --max-tokens 4400 \
    --task sentence_prediction \
    --reset-optimizer --reset-dataloader --reset-meters \
    --required-batch-size-multiple 1 \
    --init-token 0 --separator-token 2 \
    --arch linformer_roberta_base \
    --criterion sentence_prediction \
    --classification-head-name 'imdb_head' \
    --num-classes 2 \
    --dropout 0.1 --attention-dropout 0.1 \
    --weight-decay 0.1 --optimizer adam --adam-betas "(0.9, 0.98)" --adam-eps 1e-06 \
    --clip-norm 0.0 \
    --lr-scheduler polynomial_decay --lr 1e-05 --total-num-update 7812 --warmup-updates 469 \
    --fp16 --fp16-init-scale 4 --threshold-loss-scale 1 --fp16-scale-window 128 \
    --max-epoch 1 \
    --best-checkpoint-metric accuracy --maximize-best-checkpoint-metric \
    --shorten-method "truncate" \
    --find-unused-parameters \
    --update-freq 4

# %% [markdown]
# ## Twitter Dataset

# %%
# Importing the dataset from Kaggle

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'sentiment140:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F2477%2F4140%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240503%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240503T155156Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')

# %%
import pandas as pd
import tensorflow
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
import nltk
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
import spacy
import re
import sklearn
from sklearn.model_selection import train_test_split
import tqdm
nltk.download('stopwords')
STOPWORDS = set(stopwords.words('english'))
from gensim.models import Word2Vec
from tensorflow.keras import Sequential
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.pipeline import make_pipeline
from tensorflow.keras import datasets,models,layers
from tensorflow.keras.layers import Conv1D, Concatenate, GlobalMaxPooling1D, GlobalAveragePooling1D, Dense, Embedding, Input,BatchNormalization
from tensorflow.keras.models import Model

# %%
data = pd.read_csv('/kaggle/input/sentiment140/training.1600000.processed.noemoticon.csv',encoding = 'latin',header=None)
data = data[[5, 0]]
data.columns=['tweet', 'sentiment']
print(data.head())
data['sentiment'] = data['sentiment'].replace(4,1)
data = data.sample(frac = 1)
print(data.head())
# Out:
#                                                tweet  sentiment
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...          0
# 1  is upset that he can't update his Facebook by ...          0
# 2  @Kenichan I dived many times for the ball. Man...          0
# 3    my whole body feels itchy and like its on fire           0
# 4  @nationwideclass no, it's not behaving at all....          0
#                                                      tweet  sentiment
# 182120   @sarawkweird I'm the opposite. I have no unrea...          0
# 1430066  Morning Twitter  shower, food, shopping and ma...          1
# 271607   bruv's car broken into for a THIRD time! poor ...          0
# 620213                               Fed up of being sick           0
# 1547688                          @backstreetboys Hi!  #BSB          1

# %%
print(len(data))
data = data.head(160000)
print(len(data))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# Split the data into training and validation sets
train_df, dev_df = train_test_split(data, test_size=0.1, random_state=42)

train_df['tweet'].to_csv('train.input0', index=False, header=False)
train_df['sentiment'].to_csv('train.label', index=False, header=False)
dev_df['tweet'].to_csv('dev.input0', index=False, header=False)
dev_df['sentiment'].to_csv('dev.label', index=False, header=False)

# Check number of lines in each file
print("Training texts:", len(open('train.input0').readlines()))
print("Training labels:", len(open('train.label').readlines()))
print("Validation texts:", len(open('dev.input0').readlines()))
print("Validation labels:", len(open('dev.label').readlines()))
# Out:
# Training texts: 144000
# Training labels: 144000
# Validation texts: 16000
# Validation labels: 16000

# %%
# # BPE encoding of the data
# !python -m examples.roberta.multiprocessing_bpe_encoder \
    --encoder-json encoder.json \
    --vocab-bpe vocab.bpe \
    --inputs "train.input0" "dev.input0" \
    --outputs "train.input0.bpe" "dev.input0.bpe" \
    --workers 60 \
    --keep-empty

# %%
# !!wc -l train.input0
# !wc -l dev.input0
# !wc -l train.input0.bpe
# !wc -l dev.input0.bpe
# Out:
# 16000 dev.input0
# 16000 train.input0.bpe
# 16000 dev.input0.bpe

# %%
# !pip install tensorboardX

# %%
# Preprocess the data for fairseq
# !fairseq-preprocess \
    --only-source \
    --trainpref "train.input0.bpe" \
    --validpref "dev.input0.bpe" \
    --destdir "Tweet-bin/input0" \
    --srcdict dict.txt \
    --workers 60

# !fairseq-preprocess \
    --only-source \
    --trainpref "train.label" \
    --validpref "dev.label" \
    --destdir "Tweet-bin/label" \
    --workers 60

# %%
# Re-doing this process with a subset of the dataset
# !rm -rf Tweet-bin/input0 Tweet-bin/label
# !head -n 16000 train.label > train.small.label

# !fairseq-preprocess \
    --only-source \
    --trainpref "train.input0.bpe" \
    --validpref "dev.input0.bpe" \
    --destdir "Tweet-bin/input0" \
    --srcdict dict.txt \
    --workers 60

# !fairseq-preprocess \
    --only-source \
    --trainpref "train.small.label" \
    --validpref "dev.label" \
    --destdir "Tweet-bin/label" \
    --workers 60

# %%
# Training with Linformer using the Twitter data
# !fairseq-train "Tweet-bin/" \
    --user-dir /content/fairseq/examples/linformer/linformer_src \
    --max-positions 512 \
    --batch-size 16 \
    --max-tokens 4400 \
    --task sentence_prediction \
    --reset-optimizer --reset-dataloader --reset-meters \
    --required-batch-size-multiple 1 \
    --init-token 0 --separator-token 2 \
    --arch linformer_roberta_base \
    --criterion sentence_prediction \
    --classification-head-name 'sentiment_head' \
    --num-classes 2 \
    --dropout 0.1 --attention-dropout 0.1 \
    --weight-decay 0.1 --optimizer adam --adam-betas "(0.9, 0.98)" --adam-eps 1e-06 \
    --clip-norm 0.0 \
    --lr-scheduler polynomial_decay --lr 1e-05 --total-num-update 7812 --warmup-updates 469 \
    --fp16 --fp16-init-scale 4 --threshold-loss-scale 1 --fp16-scale-window 128 \
    --max-epoch 10 \
    --best-checkpoint-metric accuracy --maximize-best-checkpoint-metric \
    --shorten-method "truncate" \
    --find-unused-parameters \
    --update-freq 4

# %% [markdown]
# ## Amazon Dataset

# %%
# Step 1: Install the Hugging Face `datasets` library
# !pip install datasets

# Import the necessary library
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("amazon_polarity")

# Accessing data
train_data = dataset["train"]
test_data = dataset["test"]

# %%
print(dataset)
print(train_data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 3600000
#     })
#     test: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 400000
#     })
# })
# Dataset({
#     features: ['label', 'title', 'content'],
#     num_rows: 3600000
# })

# %%
# Print some sample data
for example in train_data.shuffle(seed=42).select(range(5)):
    print(f"Label: {example['label']}, Review Title: {example['title']}, Review Content: {example['content']}")
# Out:
# Label: 0, Review Title: Anyone who likes this better than the Pekinpah is a moron., Review Content: All the pretty people in this film. Even the Rudy character played by Michael Madsen. This is adapted from a Jim Thompson novel for cryin' out loud! These are supposed to be marginal characters, not fashion models. Though McQueen and McGraw were attractive (but check out McQueen's crummy prison haircut) they were believable in the role. Baldwin and Bassinger seem like movie stars trying to act like hard cases. Action wise, the robbery scene in the Pekinpah version was about 100 times more exciting and suspenseful than anything in this re-make.
# Label: 0, Review Title: Author seems mentally unstable, Review Content: I know that Tom Robbins has a loyal following and I started the book with high expectations. However, I did not enjoy this book as it was too much work to follow his confused logic. I think that he was under the influence during most of time that he wrote.
# Label: 1, Review Title: Spaetzle Noodles, Review Content: This type of spaetzle maker is easier to manuveur than the old press kind and much easier on the hands. The difference is that this new spaetzle maker makes smaller noodles than the old. It is great for us elderly that don't have much strength left.
# Label: 1, Review Title: Cool product until the cats lost it . . . ., Review Content: My cats seemed to be amused to work for their food. One cat would roll the ball with her paws and nose, and the other would walk behind her and eat up whatever fell out -- teamwork! I knew they'd dig this ball because I had already made something similar out of a plastic water bottle before that they liked a lot.A few weeks after getting this, though, the ball was never to be found again. I think it may have rolled down into the dark basement at some point and became one with the clutter.+1 for the adjustable hole sizes. -1 for the mess that happens when trying to put the food in by hand (although this could be solved with a funnel).
# Label: 1, Review Title: Works as expected, Review Content: I've had no problems running this with my Dell 8200 PC running Windows XP Home Edition which is running an addon USB 2 card, to which this hub (I have the 8 port version) is connected. When I bought it a year ago, I thought that 8 ports would be overkill and that 4 would be adequate, but I bought this unit anyway. Boy was I glad, right now 6 of the 8 are in use.

# %%
import pandas as pd

# Convert to pandas DataFrame
df_train = pd.DataFrame(train_data)
df_test = pd.DataFrame(test_data)

# %%
print(df_test.head())

# Assuming binary classification where 'label' 0 and 1 are used
df_train['label'] = df_train['label'].replace({4: 1})
df_test['label'] = df_test['label'].replace({4: 1})

print(df_train.head())
# Shuffle the DataFrame
df_train = df_train.sample(frac=1, random_state=42)
df_test = df_test.sample(frac=1, random_state=42)

df_train = df_train.head(25000)
df_test = df_test.head(25000)

print(df_test.head())
# Out:
#    label                                              title  \
# 0      1                                           Great CD
# 1      1  One of the best game music soundtracks - for a...
# 2      0                   Batteries died within a year ...
# 3      1              works fine, but Maha Energy is better
# 4      1                       Great for the non-audiophile
#
#                                              content
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...
#    label                                              title  \
# 0      1                     Stuning even for the non-gamer
# 1      1              The best soundtrack ever to anything.
# 2      1                                           Amazing!
# 3      1                               Excellent Soundtrack
# 4      1  Remember, Pull Your Jaw Off The Floor After He...
#
#                                              content
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...
#         label                                    title  \
# 23218       1                     This is a great book
# 20731       0                     Huge Disappointment.
# 39555       1  Wayne is tight but cant hang with Turk.
# 147506      1                                Excellent
# 314215      0                        Not about Anusara
#
#                                                   content
# 23218   I must preface this by saying that I am not re...
# 20731   As a big time, long term Trevanian fan, I was ...
# 39555   This album is hot as it wants to be. However C...
# 147506  I read this book when I was in elementary scho...
# 314215  Although this book is touted on several Anusar...

# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md  encoder.json  hubconf.py	 pyproject.toml    scripts    train.py
# CONTRIBUTING.md     examples	  hydra_plugins  README.md	   setup.cfg  vocab.bpe
# dict.txt	    fairseq	  LICENSE	 RELEASE.md	   setup.py
# docs		    fairseq_cli   MANIFEST.in	 release_utils.py  tests

# %%
df_train['title'].to_csv('train.input0', index=False, header=False)
df_train['label'].to_csv('train.label', index=False, header=False)
df_test['title'].to_csv('dev.input0', index=False, header=False)
df_test['label'].to_csv('dev.label', index=False, header=False)

# Check number of lines in each file
print("Training texts:", len(open('train.input0').readlines()))
print("Training labels:", len(open('train.label').readlines()))
print("Validation texts:", len(open('dev.input0').readlines()))
print("Validation labels:", len(open('dev.label').readlines()))
# Out:
# Training texts: 25000
# Training labels: 25000
# Validation texts: 25000
# Validation labels: 25000

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (24.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %%
# # BPE encoding of the data
# !rm -rf Amazon-bin/input0 Amazon-bin/label
# !python -m examples.roberta.multiprocessing_bpe_encoder \
    --encoder-json encoder.json \
    --vocab-bpe vocab.bpe \
    --inputs "train.input0" \
    --outputs "train.input0.bpe" \
    --workers 60 \
    --keep-empty

# !python -m examples.roberta.multiprocessing_bpe_encoder \
    --encoder-json encoder.json \
    --vocab-bpe vocab.bpe \
    --inputs "dev.input0" \
    --outputs "dev.input0.bpe" \
    --workers 60 \
    --keep-empty

# Preprocess the data for fairseq
# !fairseq-preprocess \
    --only-source \
    --trainpref "train.input0.bpe" \
    --validpref "dev.input0.bpe" \
    --destdir "Amazon-bin/input0" \
    --srcdict dict.txt \
    --workers 60

# !fairseq-preprocess \
    --only-source \
    --trainpref "train.label" \
    --validpref "dev.label" \
    --destdir "Amazon-bin/label" \
    --workers 60
# Out:
# 2024-05-05 19:09:08.812156: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 19:09:08.864980: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 19:09:08.865025: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 19:09:08.866920: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 19:09:08.875143: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-05 19:09:09.997466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# processed 10000 lines
# processed 20000 lines
# 2024-05-05 19:09:17.788752: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 19:09:17.837709: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 19:09:17.837757: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 19:09:17.839026: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 19:09:17.846091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-05 19:09:18.943479: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# processed 10000 lines
# processed 20000 lines
# 2024-05-05 19:09:26.325091: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 19:09:26.373652: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 19:09:26.373700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 19:09:26.374977: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 19:09:26.382044: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-05 19:09:27.483817: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-05 19:09:29 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe=None, optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang=None, target_lang=None, trainpref='train.input0.bpe', validpref='dev.input0.bpe', testpref=None, align_suffix=None, destdir='Amazon-bin/input0', thresholdtgt=0, thresholdsrc=0, tgtdict=None, srcdict='dict.txt', nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=False, only_source=True, padding_factor=8, workers=60, dict_only=False)
# 2024-05-05 19:09:29 | INFO | fairseq_cli.preprocess | [None] Dictionary: 50264 types
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 2024-05-05 19:09:31 | INFO | fairseq_cli.preprocess | [None] train.input0.bpe: 25000 sents, 177301 tokens, 0.0% replaced (by <unk>)
# 2024-05-05 19:09:31 | INFO | fairseq_cli.preprocess | [None] Dictionary: 50264 types
# 2024-05-05 19:09:32 | INFO | fairseq_cli.preprocess | [None] dev.input0.bpe: 25000 sents, 177589 tokens, 0.0% replaced (by <unk>)
# 2024-05-05 19:09:32 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to Amazon-bin/input0
# 2024-05-05 19:09:35.950755: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-05 19:09:36.002200: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 19:09:36.002253: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 19:09:36.003949: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 19:09:36.012016: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-05 19:09:37.114325: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-05 19:09:39 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe=None, optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang=None, target_lang=None, trainpref='train.label', validpref='dev.label', testpref=None, align_suffix=None, destdir='Amazon-bin/label', thresholdtgt=0, thresholdsrc=0, tgtdict=None, srcdict=None, nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=False, only_source=True, padding_factor=8, workers=60, dict_only=False)
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 2024-05-05 19:09:40 | INFO | fairseq_cli.preprocess | [None] Dictionary: 8 types
# 2024-05-05 19:09:40 | INFO | fairseq_cli.preprocess | [None] train.label: 25000 sents, 50000 tokens, 0.0% replaced (by <unk>)
# 2024-05-05 19:09:40 | INFO | fairseq_cli.preprocess | [None] Dictionary: 8 types
# 2024-05-05 19:09:41 | INFO | fairseq_cli.preprocess | [None] dev.label: 25000 sents, 50000 tokens, 0.0% replaced (by <unk>)
# 2024-05-05 19:09:41 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to Amazon-bin/label

# %%
# !wget -N 'https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt'
# Out:
# --2024-05-05 19:09:42--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.226.210.111, 13.226.210.15, 13.226.210.25, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.226.210.111|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘dict.txt’ not modified on server. Omitting download.

# %%
# !fairseq-train "Amazon-bin/" \
    --user-dir /content/fairseq/examples/linformer/linformer_src \
    --max-positions 512 \
    --batch-size 16 \
    --max-tokens 4400 \
    --task sentence_prediction \
    --reset-optimizer --reset-dataloader --reset-meters \
    --required-batch-size-multiple 1 \
    --init-token 0 --separator-token 2 \
    --arch linformer_roberta_base \
    --criterion sentence_prediction \
    --classification-head-name 'Amazon_head' \
    --num-classes 2 \
    --dropout 0.1 --attention-dropout 0.1 \
    --weight-decay 0.1 --optimizer adam --adam-betas "(0.9, 0.98)" --adam-eps 1e-06 \
    --clip-norm 0.0 \
    --lr-scheduler polynomial_decay --lr 1e-05 --total-num-update 7812 --warmup-updates 469 \
    --fp16 --fp16-init-scale 4 --threshold-loss-scale 1 --fp16-scale-window 128 \
    --max-epoch 10 \
    --best-checkpoint-metric accuracy --maximize-best-checkpoint-metric \
    --shorten-method "truncate" \
    --find-unused-parameters \
    --update-freq 4 \
    --shared-kv-compressed 1
# Out:
# 2024-05-06 11:47:01.926261: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-06 11:47:01.975590: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 11:47:01.975640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 11:47:01.976924: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-06 11:47:01.984105: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-06 11:47:03.068732: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-06 11:47:04 | INFO | numexpr.utils | Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-05-06 11:47:04 | INFO | numexpr.utils | NumExpr defaulting to 8 threads.
# 2024-05-06 11:47:05 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2024-05-06 11:47:07 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': True, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 4, 'fp16_scale_window': 128, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': 1.0, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': '/content/fairseq/examples/linformer/linformer_src', 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': True, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': True, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': 4400, 'batch_size': 16, 'required_batch_size_multiple': 1, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': 4400, 'batch_size_valid': 16, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 10, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [4], 'lr': [1e-05], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': True, 'reset_lr_scheduler': False, 'reset_meters': True, 'reset_optimizer': True, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'accuracy', 'maximize_best_checkpoint_metric': True, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_all_dp_ ...
# 2024-05-06 11:47:07 | INFO | fairseq.tasks.sentence_prediction | [input] dictionary: 50265 types
# 2024-05-06 11:47:07 | INFO | fairseq.tasks.sentence_prediction | [label] dictionary: 9 types
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | LinformerModel(
#   (encoder): LinformerEncoder(
#     (sentence_encoder): LinformerTransformerEncoder(
#       (dropout_module): FairseqDropout()
#       (embed_tokens): Embedding(50265, 768, padding_idx=1)
#       (embed_positions): LearnedPositionalEmbedding(514, 768, padding_idx=1)
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (layers): ModuleList(
#         (0-11): 12 x LinformerTransformerEncoderLayer(
#           (self_attn): MultiheadLinearAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (compress_k): Linear(in_features=512, out_features=170, bias=False)
#             (compress_v): Linear(in_features=512, out_features=170, bias=False)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout_module): FairseqDropout()
#           (activation_dropout_module): FairseqDropout()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (lm_head): RobertaLMHead(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (classification_heads): ModuleDict(
#     (Amazon_head): RobertaClassificationHead(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#       (out_proj): Linear(in_features=768, out_features=2, bias=True)
#     )
#   )
# )
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | task: SentencePredictionTask
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | model: LinformerModel
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | criterion: SentencePredictionCriterion
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | num. shared model params: 212,395,355 (num. trained: 212,395,355)
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2024-05-06 11:47:10 | INFO | fairseq.data.data_utils | loaded 25,000 examples from: Amazon-bin/input0/valid
# 2024-05-06 11:47:10 | INFO | fairseq.data.data_utils | loaded 25,000 examples from: Amazon-bin/label/valid
# 2024-05-06 11:47:10 | INFO | fairseq.tasks.sentence_prediction | Loaded valid with #samples: 25000
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.embed_tokens.weight <- encoder.lm_head.weight
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.0.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.1.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.1.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.2.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.2.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.3.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.3.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.4.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.4.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.5.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.5.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.6.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.6.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.7.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.7.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.8.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.8.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.9.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.9.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.10.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.10.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.11.self_attn.compress_k.bias
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | detected shared parameter: encoder.sentence_encoder.layers.0.self_attn.compress_k.bias <- encoder.sentence_encoder.layers.11.self_attn.compress_v.bias
# 2024-05-06 11:47:10 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-05-06 11:47:10 | INFO | fairseq.utils | rank   0: capabilities =  8.9  ; total memory = 22.168 GB ; name = NVIDIA L4
# 2024-05-06 11:47:10 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2024-05-06 11:47:10 | INFO | fairseq_cli.train | max tokens per device = 4400 and max sentences per device = 16
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | Preparing to load checkpoint checkpoints/checkpoint_last.pt
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | No existing checkpoint found checkpoints/checkpoint_last.pt
# 2024-05-06 11:47:10 | INFO | fairseq.trainer | loading train data for epoch 1
# 2024-05-06 11:47:10 | INFO | fairseq.data.data_utils | loaded 25,000 examples from: Amazon-bin/input0/train
# 2024-05-06 11:47:10 | INFO | fairseq.data.data_utils | loaded 25,000 examples from: Amazon-bin/label/train
# 2024-05-06 11:47:10 | INFO | fairseq.tasks.sentence_prediction | Loaded train with #samples: 25000
# 2024-05-06 11:47:11 | INFO | fairseq.data.iterators | grouped total_num_itrs = 391
# epoch 001:   0% 0/391 [00:00<?, ?it/s]2024-05-06 11:47:11 | INFO | fairseq.trainer | begin training epoch 1
# 2024-05-06 11:47:11 | INFO | fairseq_cli.train | Start iterating over samples
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# epoch 001: 100% 390/391 [01:43<00:00,  3.89it/s, loss=1.008, nll_loss=0.124, accuracy=49.1, wps=1988.7, ups=3.83, wpb=519.6, bsz=63.9, num_updates=300, lr=6.39659e-06, gnorm=2.365, loss_scale=16, train_wall=26, gb_free=17.5, wall=81]2024-05-06 11:48:55 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 001 | valid on 'valid' subset:   0% 0/1563 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:   0% 2/1563 [00:00<01:21, 19.22it/s]
# epoch 001 | valid on 'valid' subset:   1% 8/1563 [00:00<00:36, 42.69it/s]
# epoch 001 | valid on 'valid' subset:   1% 15/1563 [00:00<00:28, 53.58it/s]
# epoch 001 | valid on 'valid' subset:   1% 22/1563 [00:00<00:26, 58.84it/s]
# epoch 001 | valid on 'valid' subset:   2% 29/1563 [00:00<00:24, 61.62it/s]
# epoch 001 | valid on 'valid' subset:   2% 36/1563 [00:00<00:24, 63.45it/s]
# epoch 001 | valid on 'valid' subset:   3% 43/1563 [00:00<00:23, 64.54it/s]
# epoch 001 | valid on 'valid' subset:   3% 50/1563 [00:00<00:23, 65.36it/s]
# epoch 001 | valid on 'valid' subset:   4% 57/1563 [00:00<00:23, 65.30it/s]
# epoch 001 | valid on 'valid' subset:   4% 64/1563 [00:01<00:23, 64.79it/s]
# epoch 001 | valid on 'valid' subset:   5% 71/1563 [00:01<00:22, 65.34it/s]
# epoch 001 | valid on 'valid' subset:   5% 78/1563 [00:01<00:22, 65.18it/s]
# epoch 001 | valid on 'valid' subset:   5% 85/1563 [00:01<00:22, 65.80it/s]
# epoch 001 | valid on 'valid' subset:   6% 92/1563 [00:01<00:22, 66.27it/s]
# epoch 001 | valid on 'valid' subset:   6% 99/1563 [00:01<00:21, 66.82it/s]
# epoch 001 | valid on 'valid' subset:   7% 106/1563 [00:01<00:21, 67.17it/s]
# epoch 001 | valid on 'valid' subset:   7% 113/1563 [00:01<00:21, 66.75it/s]
# epoch 001 | valid on 'valid' subset:   8% 120/1563 [00:01<00:21, 66.58it/s]
# epoch 001 | valid on 'valid' subset:   8% 127/1563 [00:01<00:21, 66.93it/s]
# epoch 001 | valid on 'valid' subset:   9% 134/1563 [00:02<00:21, 67.16it/s]
# epoch 001 | valid on 'valid' subset:   9% 141/1563 [00:02<00:21, 66.93it/s]
# epoch 001 | valid on 'valid' subset:   9% 148/1563 [00:02<00:21, 66.62it/s]
# epoch 001 | valid on 'valid' subset:  10% 155/1563 [00:02<00:21, 66.81it/s]
# epoch 001 | valid on 'valid' subset:  10% 162/1563 [00:02<00:20, 66.80it/s]
# epoch 001 | valid on 'valid' subset:  11% 169/1563 [00:02<00:20, 67.04it/s]
# epoch 001 | valid on 'valid' subset:  11% 176/1563 [00:02<00:20, 67.10it/s]
# epoch 001 | valid on 'valid' subset:  12% 183/1563 [00:02<00:20, 67.20it/s]
# epoch 001 | valid on 'valid' subset:  12% 190/1563 [00:02<00:20, 67.21it/s]
# epoch 001 | valid on 'valid' subset:  13% 197/1563 [00:03<00:20, 67.15it/s]
# epoch 001 | valid on 'valid' subset:  13% 204/1563 [00:03<00:20, 67.22it/s]
# epoch 001 | valid on 'valid' subset:  13% 211/1563 [00:03<00:20, 67.08it/s]
# epoch 001 | valid on 'valid' subset:  14% 218/1563 [00:03<00:20, 66.86it/s]
# epoch 001 | valid on 'valid' subset:  14% 225/1563 [00:03<00:20, 66.86it/s]
# epoch 001 | valid on 'valid' subset:  15% 232/1563 [00:03<00:19, 66.66it/s]
# epoch 001 | valid on 'valid' subset:  15% 239/1563 [00:03<00:19, 66.63it/s]
# epoch 001 | valid on 'valid' subset:  16% 246/1563 [00:03<00:19, 66.60it/s]
# epoch 001 | valid on 'valid' subset:  16% 253/1563 [00:03<00:19, 66.59it/s]
# epoch 001 | valid on 'valid' subset:  17% 260/1563 [00:03<00:19, 66.67it/s]
# epoch 001 | valid on 'valid' subset:  17% 267/1563 [00:04<00:19, 66.82it/s]
# epoch 001 | valid on 'valid' subset:  18% 274/1563 [00:04<00:19, 66.94it/s]
# epoch 001 | valid on 'valid' subset:  18% 281/1563 [00:04<00:19, 66.70it/s]
# epoch 001 | valid on 'valid' subset:  18% 288/1563 [00:04<00:19, 66.59it/s]
# epoch 001 | valid on 'valid' subset:  19% 295/1563 [00:04<00:19, 66.71it/s]
# epoch 001 | valid on 'valid' subset:  19% 302/1563 [00:04<00:18, 66.85it/s]
# epoch 001 | valid on 'valid' subset:  20% 309/1563 [00:04<00:18, 66.79it/s]
# epoch 001 | valid on 'valid' subset:  20% 316/1563 [00:04<00:18, 66.92it/s]
# epoch 001 | valid on 'valid' subset:  21% 323/1563 [00:04<00:18, 67.11it/s]
# epoch 001 | valid on 'valid' subset:  21% 330/1563 [00:05<00:18, 67.07it/s]
# epoch 001 | valid on 'valid' subset:  22% 337/1563 [00:05<00:18, 66.93it/s]
# epoch 001 | valid on 'valid' subset:  22% 344/1563 [00:05<00:18, 66.37it/s]
# epoch 001 | valid on 'valid' subset:  22% 351/1563 [00:05<00:18, 66.38it/s]
# epoch 001 | valid on 'valid' subset:  23% 358/1563 [00:05<00:18, 66.68it/s]
# epoch 001 | valid on 'valid' subset:  23% 365/1563 [00:05<00:17, 66.62it/s]
# epoch 001 | valid on 'valid' subset:  24% 372/1563 [00:05<00:17, 66.48it/s]
# epoch 001 | valid on 'valid' subset:  24% 379/1563 [00:05<00:17, 66.52it/s]
# epoch 001 | valid on 'valid' subset:  25% 386/1563 [00:05<00:17, 66.55it/s]
# epoch 001 | valid on 'valid' subset:  25% 393/1563 [00:05<00:17, 66.47it/s]
# epoch 001 | valid on 'valid' subset:  26% 400/1563 [00:06<00:17, 66.48it/s]
# epoch 001 | valid on 'valid' subset:  26% 407/1563 [00:06<00:17, 66.40it/s]
# epoch 001 | valid on 'valid' subset:  26% 414/1563 [00:06<00:17, 66.38it/s]
# epoch 001 | valid on 'valid' subset:  27% 421/1563 [00:06<00:17, 66.59it/s]
# epoch 001 | valid on 'valid' subset:  27% 428/1563 [00:06<00:16, 66.84it/s]
# epoch 001 | valid on 'valid' subset:  28% 435/1563 [00:06<00:16, 66.77it/s]
# epoch 001 | valid on 'valid' subset:  28% 442/1563 [00:06<00:16, 66.92it/s]
# epoch 001 | valid on 'valid' subset:  29% 449/1563 [00:06<00:16, 67.07it/s]
# epoch 001 | valid on 'valid' subset:  29% 456/1563 [00:06<00:16, 67.31it/s]
# epoch 001 | valid on 'valid' subset:  30% 463/1563 [00:07<00:16, 67.17it/s]
# epoch 001 | valid on 'valid' subset:  30% 470/1563 [00:07<00:16, 66.96it/s]
# epoch 001 | valid on 'valid' subset:  31% 477/1563 [00:07<00:16, 66.43it/s]
# epoch 001 | valid on 'valid' subset:  31% 484/1563 [00:07<00:16, 66.56it/s]
# epoch 001 | valid on 'valid' subset:  31% 491/1563 [00:07<00:16, 66.91it/s]
# epoch 001 | valid on 'valid' subset:  32% 498/1563 [00:07<00:15, 66.94it/s]
# epoch 001 | valid on 'valid' subset:  32% 505/1563 [00:07<00:15, 67.13it/s]
# epoch 001 | valid on 'valid' subset:  33% 512/1563 [00:07<00:15, 67.21it/s]
# epoch 001 | valid on 'valid' subset:  33% 519/1563 [00:07<00:15, 67.14it/s]
# epoch 001 | valid on 'valid' subset:  34% 526/1563 [00:07<00:15, 67.11it/s]
# epoch 001 | valid on 'valid' subset:  34% 533/1563 [00:08<00:15, 67.02it/s]
# epoch 001 | valid on 'valid' subset:  35% 540/1563 [00:08<00:15, 66.67it/s]
# epoch 001 | valid on 'valid' subset:  35% 547/1563 [00:08<00:15, 66.50it/s]
# epoch 001 | valid on 'valid' subset:  35% 554/1563 [00:08<00:15, 66.04it/s]
# epoch 001 | valid on 'valid' subset:  36% 561/1563 [00:08<00:15, 65.99it/s]
# epoch 001 | valid on 'valid' subset:  36% 568/1563 [00:08<00:15, 66.16it/s]
# epoch 001 | valid on 'valid' subset:  37% 575/1563 [00:08<00:14, 66.38it/s]
# epoch 001 | valid on 'valid' subset:  37% 582/1563 [00:08<00:14, 66.78it/s]
# epoch 001 | valid on 'valid' subset:  38% 589/1563 [00:08<00:14, 66.98it/s]
# epoch 001 | valid on 'valid' subset:  38% 596/1563 [00:09<00:14, 66.36it/s]
# epoch 001 | valid on 'valid' subset:  39% 603/1563 [00:09<00:14, 66.46it/s]
# epoch 001 | valid on 'valid' subset:  39% 610/1563 [00:09<00:14, 66.91it/s]
# epoch 001 | valid on 'valid' subset:  39% 617/1563 [00:09<00:14, 67.05it/s]
# epoch 001 | valid on 'valid' subset:  40% 624/1563 [00:09<00:14, 66.65it/s]
# epoch 001 | valid on 'valid' subset:  40% 631/1563 [00:09<00:13, 66.61it/s]
# epoch 001 | valid on 'valid' subset:  41% 638/1563 [00:09<00:13, 66.85it/s]
# epoch 001 | valid on 'valid' subset:  41% 645/1563 [00:09<00:13, 66.86it/s]
# epoch 001 | valid on 'valid' subset:  42% 652/1563 [00:09<00:13, 66.82it/s]
# epoch 001 | valid on 'valid' subset:  42% 659/1563 [00:09<00:13, 67.11it/s]
# epoch 001 | valid on 'valid' subset:  43% 666/1563 [00:10<00:13, 67.39it/s]
# epoch 001 | valid on 'valid' subset:  43% 673/1563 [00:10<00:13, 67.67it/s]
# epoch 001 | valid on 'valid' subset:  44% 680/1563 [00:10<00:13, 67.22it/s]
# epoch 001 | valid on 'valid' subset:  44% 687/1563 [00:10<00:13, 67.07it/s]
# epoch 001 | valid on 'valid' subset:  44% 694/1563 [00:10<00:12, 67.20it/s]
# epoch 001 | valid on 'valid' subset:  45% 701/1563 [00:10<00:12, 67.50it/s]
# epoch 001 | valid on 'valid' subset:  45% 708/1563 [00:10<00:12, 67.62it/s]
# epoch 001 | valid on 'valid' subset:  46% 715/1563 [00:10<00:12, 67.57it/s]
# epoch 001 | valid on 'valid' subset:  46% 722/1563 [00:10<00:12, 67.66it/s]
# epoch 001 | valid on 'valid' subset:  47% 729/1563 [00:10<00:12, 67.62it/s]
# epoch 001 | valid on 'valid' subset:  47% 736/1563 [00:11<00:12, 67.74it/s]
# epoch 001 | valid on 'valid' subset:  48% 743/1563 [00:11<00:12, 67.90it/s]
# epoch 001 | valid on 'valid' subset:  48% 750/1563 [00:11<00:12, 67.54it/s]
# epoch 001 | valid on 'valid' subset:  48% 757/1563 [00:11<00:12, 66.55it/s]
# epoch 001 | valid on 'valid' subset:  49% 764/1563 [00:11<00:11, 66.93it/s]
# epoch 001 | valid on 'valid' subset:  49% 771/1563 [00:11<00:11, 67.35it/s]
# epoch 001 | valid on 'valid' subset:  50% 778/1563 [00:11<00:11, 67.62it/s]
# epoch 001 | valid on 'valid' subset:  50% 785/1563 [00:11<00:11, 67.75it/s]
# epoch 001 | valid on 'valid' subset:  51% 792/1563 [00:11<00:11, 67.91it/s]
# epoch 001 | valid on 'valid' subset:  51% 799/1563 [00:12<00:11, 67.97it/s]
# epoch 001 | valid on 'valid' subset:  52% 806/1563 [00:12<00:11, 67.88it/s]
# epoch 001 | valid on 'valid' subset:  52% 813/1563 [00:12<00:11, 67.47it/s]
# epoch 001 | valid on 'valid' subset:  52% 820/1563 [00:12<00:11, 67.50it/s]
# epoch 001 | valid on 'valid' subset:  53% 827/1563 [00:12<00:11, 66.65it/s]
# epoch 001 | valid on 'valid' subset:  53% 834/1563 [00:12<00:10, 66.65it/s]
# epoch 001 | valid on 'valid' subset:  54% 841/1563 [00:12<00:10, 66.71it/s]
# epoch 001 | valid on 'valid' subset:  54% 848/1563 [00:12<00:10, 66.57it/s]
# epoch 001 | valid on 'valid' subset:  55% 855/1563 [00:12<00:10, 66.57it/s]
# epoch 001 | valid on 'valid' subset:  55% 862/1563 [00:12<00:10, 66.41it/s]
# epoch 001 | valid on 'valid' subset:  56% 869/1563 [00:13<00:10, 66.72it/s]
# epoch 001 | valid on 'valid' subset:  56% 876/1563 [00:13<00:10, 66.44it/s]
# epoch 001 | valid on 'valid' subset:  56% 883/1563 [00:13<00:10, 66.67it/s]
# epoch 001 | valid on 'valid' subset:  57% 890/1563 [00:13<00:10, 66.60it/s]
# epoch 001 | valid on 'valid' subset:  57% 897/1563 [00:13<00:10, 66.45it/s]
# epoch 001 | valid on 'valid' subset:  58% 904/1563 [00:13<00:09, 66.43it/s]
# epoch 001 | valid on 'valid' subset:  58% 911/1563 [00:13<00:09, 65.80it/s]
# epoch 001 | valid on 'valid' subset:  59% 918/1563 [00:13<00:09, 65.81it/s]
# epoch 001 | valid on 'valid' subset:  59% 925/1563 [00:13<00:09, 66.29it/s]
# epoch 001 | valid on 'valid' subset:  60% 932/1563 [00:14<00:09, 66.57it/s]
# epoch 001 | valid on 'valid' subset:  60% 939/1563 [00:14<00:09, 66.89it/s]
# epoch 001 | valid on 'valid' subset:  61% 946/1563 [00:14<00:09, 67.04it/s]
# epoch 001 | valid on 'valid' subset:  61% 953/1563 [00:14<00:09, 66.87it/s]
# epoch 001 | valid on 'valid' subset:  61% 960/1563 [00:14<00:09, 66.99it/s]
# epoch 001 | valid on 'valid' subset:  62% 967/1563 [00:14<00:08, 66.62it/s]
# epoch 001 | valid on 'valid' subset:  62% 974/1563 [00:14<00:08, 66.75it/s]
# epoch 001 | valid on 'valid' subset:  63% 981/1563 [00:14<00:08, 66.79it/s]
# epoch 001 | valid on 'valid' subset:  63% 988/1563 [00:14<00:08, 66.92it/s]
# epoch 001 | valid on 'valid' subset:  64% 995/1563 [00:14<00:08, 66.96it/s]
# epoch 001 | valid on 'valid' subset:  64% 1002/1563 [00:15<00:08, 67.01it/s]
# epoch 001 | valid on 'valid' subset:  65% 1009/1563 [00:15<00:08, 66.96it/s]
# epoch 001 | valid on 'valid' subset:  65% 1016/1563 [00:15<00:08, 67.13it/s]
# epoch 001 | valid on 'valid' subset:  65% 1023/1563 [00:15<00:08, 66.58it/s]
# epoch 001 | valid on 'valid' subset:  66% 1030/1563 [00:15<00:08, 66.48it/s]
# epoch 001 | valid on 'valid' subset:  66% 1037/1563 [00:15<00:07, 66.67it/s]
# epoch 001 | valid on 'valid' subset:  67% 1044/1563 [00:15<00:07, 66.71it/s]
# epoch 001 | valid on 'valid' subset:  67% 1051/1563 [00:15<00:07, 66.77it/s]
# epoch 001 | valid on 'valid' subset:  68% 1058/1563 [00:15<00:07, 66.94it/s]
# epoch 001 | valid on 'valid' subset:  68% 1065/1563 [00:16<00:07, 66.82it/s]
# epoch 001 | valid on 'valid' subset:  69% 1072/1563 [00:16<00:07, 66.62it/s]
# epoch 001 | valid on 'valid' subset:  69% 1079/1563 [00:16<00:07, 66.31it/s]
# epoch 001 | valid on 'valid' subset:  69% 1086/1563 [00:16<00:07, 66.71it/s]
# epoch 001 | valid on 'valid' subset:  70% 1093/1563 [00:16<00:07, 66.81it/s]
# epoch 001 | valid on 'valid' subset:  70% 1100/1563 [00:16<00:06, 66.71it/s]
# epoch 001 | valid on 'valid' subset:  71% 1107/1563 [00:16<00:06, 66.85it/s]
# epoch 001 | valid on 'valid' subset:  71% 1114/1563 [00:16<00:06, 67.11it/s]
# epoch 001 | valid on 'valid' subset:  72% 1121/1563 [00:16<00:06, 67.29it/s]
# epoch 001 | valid on 'valid' subset:  72% 1128/1563 [00:16<00:06, 67.34it/s]
# epoch 001 | valid on 'valid' subset:  73% 1135/1563 [00:17<00:06, 67.38it/s]
# epoch 001 | valid on 'valid' subset:  73% 1142/1563 [00:17<00:06, 67.38it/s]
# epoch 001 | valid on 'valid' subset:  74% 1149/1563 [00:17<00:06, 67.35it/s]
# epoch 001 | valid on 'valid' subset:  74% 1156/1563 [00:17<00:06, 67.23it/s]
# epoch 001 | valid on 'valid' subset:  74% 1163/1563 [00:17<00:05, 67.38it/s]
# epoch 001 | valid on 'valid' subset:  75% 1170/1563 [00:17<00:06, 65.28it/s]
# epoch 001 | valid on 'valid' subset:  75% 1177/1563 [00:17<00:05, 65.84it/s]
# epoch 001 | valid on 'valid' subset:  76% 1184/1563 [00:17<00:05, 66.04it/s]
# epoch 001 | valid on 'valid' subset:  76% 1191/1563 [00:17<00:05, 66.42it/s]
# epoch 001 | valid on 'valid' subset:  77% 1198/1563 [00:18<00:05, 66.58it/s]
# epoch 001 | valid on 'valid' subset:  77% 1205/1563 [00:18<00:05, 67.04it/s]
# epoch 001 | valid on 'valid' subset:  78% 1212/1563 [00:18<00:05, 67.25it/s]
# epoch 001 | valid on 'valid' subset:  78% 1219/1563 [00:18<00:05, 67.43it/s]
# epoch 001 | valid on 'valid' subset:  78% 1226/1563 [00:18<00:04, 67.58it/s]
# epoch 001 | valid on 'valid' subset:  79% 1233/1563 [00:18<00:04, 67.69it/s]
# epoch 001 | valid on 'valid' subset:  79% 1240/1563 [00:18<00:04, 65.56it/s]
# epoch 001 | valid on 'valid' subset:  80% 1247/1563 [00:18<00:04, 65.84it/s]
# epoch 001 | valid on 'valid' subset:  80% 1254/1563 [00:18<00:04, 66.37it/s]
# epoch 001 | valid on 'valid' subset:  81% 1261/1563 [00:18<00:04, 66.46it/s]
# epoch 001 | valid on 'valid' subset:  81% 1268/1563 [00:19<00:04, 66.87it/s]
# epoch 001 | valid on 'valid' subset:  82% 1275/1563 [00:19<00:04, 66.65it/s]
# epoch 001 | valid on 'valid' subset:  82% 1282/1563 [00:19<00:04, 66.57it/s]
# epoch 001 | valid on 'valid' subset:  82% 1289/1563 [00:19<00:04, 66.24it/s]
# epoch 001 | valid on 'valid' subset:  83% 1296/1563 [00:19<00:04, 66.42it/s]
# epoch 001 | valid on 'valid' subset:  83% 1303/1563 [00:19<00:03, 66.42it/s]
# epoch 001 | valid on 'valid' subset:  84% 1310/1563 [00:19<00:03, 65.90it/s]
# epoch 001 | valid on 'valid' subset:  84% 1317/1563 [00:19<00:03, 65.46it/s]
# epoch 001 | valid on 'valid' subset:  85% 1324/1563 [00:19<00:03, 65.49it/s]
# epoch 001 | valid on 'valid' subset:  85% 1331/1563 [00:20<00:03, 65.54it/s]
# epoch 001 | valid on 'valid' subset:  86% 1338/1563 [00:20<00:03, 65.63it/s]
# epoch 001 | valid on 'valid' subset:  86% 1345/1563 [00:20<00:03, 65.91it/s]
# epoch 001 | valid on 'valid' subset:  87% 1352/1563 [00:20<00:03, 66.13it/s]
# epoch 001 | valid on 'valid' subset:  87% 1359/1563 [00:20<00:03, 65.88it/s]
# epoch 001 | valid on 'valid' subset:  87% 1366/1563 [00:20<00:02, 66.06it/s]
# epoch 001 | valid on 'valid' subset:  88% 1373/1563 [00:20<00:02, 66.17it/s]
# epoch 001 | valid on 'valid' subset:  88% 1380/1563 [00:20<00:02, 66.44it/s]
# epoch 001 | valid on 'valid' subset:  89% 1387/1563 [00:20<00:02, 66.73it/s]
# epoch 001 | valid on 'valid' subset:  89% 1394/1563 [00:20<00:02, 66.84it/s]
# epoch 001 | valid on 'valid' subset:  90% 1401/1563 [00:21<00:02, 67.01it/s]
# epoch 001 | valid on 'valid' subset:  90% 1408/1563 [00:21<00:02, 66.93it/s]
# epoch 001 | valid on 'valid' subset:  91% 1415/1563 [00:21<00:02, 66.94it/s]
# epoch 001 | valid on 'valid' subset:  91% 1422/1563 [00:21<00:02, 66.49it/s]
# epoch 001 | valid on 'valid' subset:  91% 1429/1563 [00:21<00:02, 66.47it/s]
# epoch 001 | valid on 'valid' subset:  92% 1436/1563 [00:21<00:01, 66.55it/s]
# epoch 001 | valid on 'valid' subset:  92% 1443/1563 [00:21<00:01, 66.50it/s]
# epoch 001 | valid on 'valid' subset:  93% 1450/1563 [00:21<00:01, 66.73it/s]
# epoch 001 | valid on 'valid' subset:  93% 1457/1563 [00:21<00:01, 66.73it/s]
# epoch 001 | valid on 'valid' subset:  94% 1464/1563 [00:22<00:01, 66.90it/s]
# epoch 001 | valid on 'valid' subset:  94% 1471/1563 [00:22<00:01, 67.18it/s]
# epoch 001 | valid on 'valid' subset:  95% 1478/1563 [00:22<00:01, 67.18it/s]
# epoch 001 | valid on 'valid' subset:  95% 1485/1563 [00:22<00:01, 67.30it/s]
# epoch 001 | valid on 'valid' subset:  95% 1492/1563 [00:22<00:01, 67.38it/s]
# epoch 001 | valid on 'valid' subset:  96% 1499/1563 [00:22<00:00, 67.42it/s]
# epoch 001 | valid on 'valid' subset:  96% 1506/1563 [00:22<00:00, 67.60it/s]
# epoch 001 | valid on 'valid' subset:  97% 1513/1563 [00:22<00:00, 67.16it/s]
# epoch 001 | valid on 'valid' subset:  97% 1520/1563 [00:22<00:00, 67.28it/s]
# epoch 001 | valid on 'valid' subset:  98% 1527/1563 [00:22<00:00, 67.35it/s]
# epoch 001 | valid on 'valid' subset:  98% 1534/1563 [00:23<00:00, 67.46it/s]
# epoch 001 | valid on 'valid' subset:  99% 1541/1563 [00:23<00:00, 67.37it/s]
# epoch 001 | valid on 'valid' subset:  99% 1548/1563 [00:23<00:00, 67.38it/s]
# epoch 001 | valid on 'valid' subset: 100% 1556/1563 [00:23<00:00, 69.31it/s]
#                                                                             2024-05-06 11:49:19 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 1.034 | nll_loss 0.128 | accuracy 49.8 | wps 8658.2 | wpb 129.6 | bsz 16 | num_updates 391
# 2024-05-06 11:49:19 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 391 updates
# 2024-05-06 11:49:19 | INFO | fairseq.trainer | Saving checkpoint to /content/fairseq/checkpoints/checkpoint1.pt
# 2024-05-06 11:49:27 | INFO | fairseq.trainer | Finished saving checkpoint to /content/fairseq/checkpoints/checkpoint1.pt
# 2024-05-06 11:49:45 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint1.pt (epoch 1 @ 391 updates, score 49.8) (writing took 26.654090017999806 seconds)
# 2024-05-06 11:49:45 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2024-05-06 11:49:45 | INFO | train | epoch 001 | loss 1.007 | nll_loss 0.124 | accuracy 50 | wps 1322.8 | ups 2.56 | wpb 517.4 | bsz 63.9 | num_updates 391 | lr 8.33689e-06 | gnorm 2.416 | loss_scale 32 | train_wall 103 | gb_free 17.5 | wall 155
# 2024-05-06 11:49:45 | INFO | fairseq.data.iterators | grouped total_num_itrs = 391
# epoch 002:   0% 0/391 [00:00<?, ?it/s]2024-05-06 11:49:45 | INFO | fairseq.trainer | begin training epoch 2
# 2024-05-06 11:49:45 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002: 100% 390/391 [01:42<00:00,  3.86it/s, loss=0.887, nll_loss=0.109, accuracy=63.3, wps=1967.4, ups=3.79, wpb=519.5, bsz=64, num_updates=700, lr=9.68541e-06, gnorm=9.581, loss_scale=128, train_wall=26, gb_free=17.5, wall=237]2024-05-06 11:51:28 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 002 | valid on 'valid' subset:   0% 0/1563 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   0% 3/1563 [00:00<00:59, 26.37it/s]
# epoch 002 | valid on 'valid' subset:   1% 10/1563 [00:00<00:31, 49.17it/s]
# epoch 002 | valid on 'valid' subset:   1% 17/1563 [00:00<00:26, 57.33it/s]
# epoch 002 | valid on 'valid' subset:   2% 24/1563 [00:00<00:25, 61.29it/s]
# epoch 002 | valid on 'valid' subset:   2% 31/1563 [00:00<00:24, 63.12it/s]
# epoch 002 | valid on 'valid' subset:   2% 38/1563 [00:00<00:23, 63.74it/s]
# epoch 002 | valid on 'valid' subset:   3% 45/1563 [00:00<00:23, 64.83it/s]
# epoch 002 | valid on 'valid' subset:   3% 52/1563 [00:00<00:23, 65.51it/s]
# epoch 002 | valid on 'valid' subset:   4% 59/1563 [00:00<00:22, 65.93it/s]
# epoch 002 | valid on 'valid' subset:   4% 66/1563 [00:01<00:22, 66.15it/s]
# epoch 002 | valid on 'valid' subset:   5% 73/1563 [00:01<00:22, 65.16it/s]
# epoch 002 | valid on 'valid' subset:   5% 80/1563 [00:01<00:22, 64.96it/s]
# epoch 002 | valid on 'valid' subset:   6% 87/1563 [00:01<00:22, 65.18it/s]
# epoch 002 | valid on 'valid' subset:   6% 94/1563 [00:01<00:22, 65.66it/s]
# epoch 002 | valid on 'valid' subset:   6% 101/1563 [00:01<00:22, 64.89it/s]
# epoch 002 | valid on 'valid' subset:   7% 108/1563 [00:01<00:22, 65.53it/s]
# epoch 002 | valid on 'valid' subset:   7% 115/1563 [00:01<00:22, 65.53it/s]
# epoch 002 | valid on 'valid' subset:   8% 122/1563 [00:01<00:22, 64.74it/s]
# epoch 002 | valid on 'valid' subset:   8% 129/1563 [00:02<00:22, 64.91it/s]
# epoch 002 | valid on 'valid' subset:   9% 136/1563 [00:02<00:21, 65.53it/s]
# epoch 002 | valid on 'valid' subset:   9% 143/1563 [00:02<00:21, 66.08it/s]
# epoch 002 | valid on 'valid' subset:  10% 150/1563 [00:02<00:21, 66.31it/s]
# epoch 002 | valid on 'valid' subset:  10% 157/1563 [00:02<00:21, 66.51it/s]
# epoch 002 | valid on 'valid' subset:  10% 164/1563 [00:02<00:21, 66.60it/s]
# epoch 002 | valid on 'valid' subset:  11% 171/1563 [00:02<00:21, 64.79it/s]
# epoch 002 | valid on 'valid' subset:  11% 178/1563 [00:02<00:21, 65.56it/s]
# epoch 002 | valid on 'valid' subset:  12% 185/1563 [00:02<00:20, 65.91it/s]
# epoch 002 | valid on 'valid' subset:  12% 192/1563 [00:02<00:20, 66.12it/s]
# epoch 002 | valid on 'valid' subset:  13% 199/1563 [00:03<00:20, 66.40it/s]
# epoch 002 | valid on 'valid' subset:  13% 206/1563 [00:03<00:20, 66.31it/s]
# epoch 002 | valid on 'valid' subset:  14% 213/1563 [00:03<00:20, 65.93it/s]
# epoch 002 | valid on 'valid' subset:  14% 220/1563 [00:03<00:20, 65.54it/s]
# epoch 002 | valid on 'valid' subset:  15% 227/1563 [00:03<00:20, 64.72it/s]
# epoch 002 | valid on 'valid' subset:  15% 234/1563 [00:03<00:20, 64.32it/s]
# epoch 002 | valid on 'valid' subset:  15% 241/1563 [00:03<00:21, 62.28it/s]
# epoch 002 | valid on 'valid' subset:  16% 248/1563 [00:03<00:21, 62.57it/s]
# epoch 002 | valid on 'valid' subset:  16% 255/1563 [00:03<00:20, 62.90it/s]
# epoch 002 | valid on 'valid' subset:  17% 262/1563 [00:04<00:20, 62.83it/s]
# epoch 002 | valid on 'valid' subset:  17% 269/1563 [00:04<00:21, 61.56it/s]
# epoch 002 | valid on 'valid' subset:  18% 276/1563 [00:04<00:21, 59.95it/s]
# epoch 002 | valid on 'valid' subset:  18% 283/1563 [00:04<00:21, 58.55it/s]
# epoch 002 | valid on 'valid' subset:  19% 290/1563 [00:04<00:21, 59.02it/s]
# epoch 002 | valid on 'valid' subset:  19% 296/1563 [00:04<00:21, 59.13it/s]
# epoch 002 | valid on 'valid' subset:  19% 303/1563 [00:04<00:20, 60.65it/s]
# epoch 002 | valid on 'valid' subset:  20% 310/1563 [00:04<00:20, 62.53it/s]
# epoch 002 | valid on 'valid' subset:  20% 317/1563 [00:04<00:19, 63.73it/s]
# epoch 002 | valid on 'valid' subset:  21% 324/1563 [00:05<00:19, 64.53it/s]
# epoch 002 | valid on 'valid' subset:  21% 331/1563 [00:05<00:18, 65.25it/s]
# epoch 002 | valid on 'valid' subset:  22% 338/1563 [00:05<00:18, 65.94it/s]
# epoch 002 | valid on 'valid' subset:  22% 345/1563 [00:05<00:18, 66.33it/s]
# epoch 002 | valid on 'valid' subset:  23% 352/1563 [00:05<00:18, 66.65it/s]
# epoch 002 | valid on 'valid' subset:  23% 359/1563 [00:05<00:18, 66.80it/s]
# epoch 002 | valid on 'valid' subset:  23% 366/1563 [00:05<00:17, 66.72it/s]
# epoch 002 | valid on 'valid' subset:  24% 373/1563 [00:05<00:17, 66.97it/s]
# epoch 002 | valid on 'valid' subset:  24% 380/1563 [00:05<00:17, 67.10it/s]
# epoch 002 | valid on 'valid' subset:  25% 387/1563 [00:06<00:17, 67.10it/s]
# epoch 002 | valid on 'valid' subset:  25% 394/1563 [00:06<00:17, 66.98it/s]
# epoch 002 | valid on 'valid' subset:  26% 401/1563 [00:06<00:17, 67.04it/s]
# epoch 002 | valid on 'valid' subset:  26% 408/1563 [00:06<00:17, 67.05it/s]
# epoch 002 | valid on 'valid' subset:  27% 415/1563 [00:06<00:17, 67.06it/s]
# epoch 002 | valid on 'valid' subset:  27% 422/1563 [00:06<00:17, 66.85it/s]
# epoch 002 | valid on 'valid' subset:  27% 429/1563 [00:06<00:17, 66.67it/s]
# epoch 002 | valid on 'valid' subset:  28% 436/1563 [00:06<00:17, 66.19it/s]
# epoch 002 | valid on 'valid' subset:  28% 443/1563 [00:06<00:16, 66.33it/s]
# epoch 002 | valid on 'valid' subset:  29% 450/1563 [00:06<00:16, 66.47it/s]
# epoch 002 | valid on 'valid' subset:  29% 457/1563 [00:07<00:16, 66.43it/s]
# epoch 002 | valid on 'valid' subset:  30% 464/1563 [00:07<00:16, 66.40it/s]
# epoch 002 | valid on 'valid' subset:  30% 471/1563 [00:07<00:16, 66.31it/s]
# epoch 002 | valid on 'valid' subset:  31% 478/1563 [00:07<00:16, 65.92it/s]
# epoch 002 | valid on 'valid' subset:  31% 485/1563 [00:07<00:16, 65.81it/s]
# epoch 002 | valid on 'valid' subset:  31% 492/1563 [00:07<00:16, 65.59it/s]
# epoch 002 | valid on 'valid' subset:  32% 499/1563 [00:07<00:16, 65.59it/s]
# epoch 002 | valid on 'valid' subset:  32% 506/1563 [00:07<00:16, 65.81it/s]
# epoch 002 | valid on 'valid' subset:  33% 513/1563 [00:07<00:15, 65.95it/s]
# epoch 002 | valid on 'valid' subset:  33% 520/1563 [00:08<00:15, 65.66it/s]
# epoch 002 | valid on 'valid' subset:  34% 527/1563 [00:08<00:15, 65.57it/s]
# epoch 002 | valid on 'valid' subset:  34% 534/1563 [00:08<00:15, 65.60it/s]
# epoch 002 | valid on 'valid' subset:  35% 541/1563 [00:08<00:15, 65.54it/s]
# epoch 002 | valid on 'valid' subset:  35% 548/1563 [00:08<00:15, 65.26it/s]
# epoch 002 | valid on 'valid' subset:  36% 555/1563 [00:08<00:15, 65.56it/s]
# epoch 002 | valid on 'valid' subset:  36% 562/1563 [00:08<00:15, 65.99it/s]
# epoch 002 | valid on 'valid' subset:  36% 569/1563 [00:08<00:15, 66.25it/s]
# epoch 002 | valid on 'valid' subset:  37% 576/1563 [00:08<00:14, 66.48it/s]
# epoch 002 | valid on 'valid' subset:  37% 583/1563 [00:08<00:14, 66.45it/s]
# epoch 002 | valid on 'valid' subset:  38% 590/1563 [00:09<00:14, 66.65it/s]
# epoch 002 | valid on 'valid' subset:  38% 597/1563 [00:09<00:14, 66.85it/s]
# epoch 002 | valid on 'valid' subset:  39% 604/1563 [00:09<00:14, 66.91it/s]
# epoch 002 | valid on 'valid' subset:  39% 611/1563 [00:09<00:14, 67.03it/s]
# epoch 002 | valid on 'valid' subset:  40% 618/1563 [00:09<00:14, 67.14it/s]
# epoch 002 | valid on 'valid' subset:  40% 625/1563 [00:09<00:13, 67.17it/s]
# epoch 002 | valid on 'valid' subset:  40% 632/1563 [00:09<00:13, 66.98it/s]
# epoch 002 | valid on 'valid' subset:  41% 639/1563 [00:09<00:13, 66.94it/s]
# epoch 002 | valid on 'valid' subset:  41% 646/1563 [00:09<00:13, 67.01it/s]
# epoch 002 | valid on 'valid' subset:  42% 653/1563 [00:10<00:13, 67.04it/s]
# epoch 002 | valid on 'valid' subset:  42% 660/1563 [00:10<00:13, 66.75it/s]
# epoch 002 | valid on 'valid' subset:  43% 667/1563 [00:10<00:13, 66.78it/s]
# epoch 002 | valid on 'valid' subset:  43% 674/1563 [00:10<00:13, 66.81it/s]
# epoch 002 | valid on 'valid' subset:  44% 681/1563 [00:10<00:13, 66.86it/s]
# epoch 002 | valid on 'valid' subset:  44% 688/1563 [00:10<00:13, 66.50it/s]
# epoch 002 | valid on 'valid' subset:  44% 695/1563 [00:10<00:13, 66.42it/s]
# epoch 002 | valid on 'valid' subset:  45% 702/1563 [00:10<00:12, 66.43it/s]
# epoch 002 | valid on 'valid' subset:  45% 709/1563 [00:10<00:12, 66.27it/s]
# epoch 002 | valid on 'valid' subset:  46% 716/1563 [00:10<00:12, 66.19it/s]
# epoch 002 | valid on 'valid' subset:  46% 723/1563 [00:11<00:12, 66.12it/s]
# epoch 002 | valid on 'valid' subset:  47% 730/1563 [00:11<00:12, 66.30it/s]
# epoch 002 | valid on 'valid' subset:  47% 737/1563 [00:11<00:12, 66.47it/s]
# epoch 002 | valid on 'valid' subset:  48% 744/1563 [00:11<00:12, 66.58it/s]
# epoch 002 | valid on 'valid' subset:  48% 751/1563 [00:11<00:12, 66.54it/s]
# epoch 002 | valid on 'valid' subset:  48% 758/1563 [00:11<00:12, 66.56it/s]
# epoch 002 | valid on 'valid' subset:  49% 765/1563 [00:11<00:12, 66.17it/s]
# epoch 002 | valid on 'valid' subset:  49% 772/1563 [00:11<00:12, 65.55it/s]
# epoch 002 | valid on 'valid' subset:  50% 779/1563 [00:11<00:12, 65.22it/s]
# epoch 002 | valid on 'valid' subset:  50% 786/1563 [00:12<00:11, 65.04it/s]
# epoch 002 | valid on 'valid' subset:  51% 793/1563 [00:12<00:11, 64.93it/s]
# epoch 002 | valid on 'valid' subset:  51% 800/1563 [00:12<00:11, 64.80it/s]
# epoch 002 | valid on 'valid' subset:  52% 807/1563 [00:12<00:11, 64.85it/s]
# epoch 002 | valid on 'valid' subset:  52% 814/1563 [00:12<00:11, 64.99it/s]
# epoch 002 | valid on 'valid' subset:  53% 821/1563 [00:12<00:11, 64.55it/s]
# epoch 002 | valid on 'valid' subset:  53% 828/1563 [00:12<00:11, 63.98it/s]
# epoch 002 | valid on 'valid' subset:  53% 835/1563 [00:12<00:11, 64.03it/s]
# epoch 002 | valid on 'valid' subset:  54% 842/1563 [00:12<00:11, 64.08it/s]
# epoch 002 | valid on 'valid' subset:  54% 849/1563 [00:13<00:11, 64.16it/s]
# epoch 002 | valid on 'valid' subset:  55% 856/1563 [00:13<00:10, 64.73it/s]
# epoch 002 | valid on 'valid' subset:  55% 863/1563 [00:13<00:10, 64.92it/s]
# epoch 002 | valid on 'valid' subset:  56% 870/1563 [00:13<00:10, 64.12it/s]
# epoch 002 | valid on 'valid' subset:  56% 877/1563 [00:13<00:10, 63.22it/s]
# epoch 002 | valid on 'valid' subset:  57% 884/1563 [00:13<00:10, 62.68it/s]
# epoch 002 | valid on 'valid' subset:  57% 891/1563 [00:13<00:10, 62.50it/s]
# epoch 002 | valid on 'valid' subset:  57% 898/1563 [00:13<00:10, 62.13it/s]
# epoch 002 | valid on 'valid' subset:  58% 905/1563 [00:13<00:10, 61.59it/s]
# epoch 002 | valid on 'valid' subset:  58% 912/1563 [00:14<00:10, 61.42it/s]
# epoch 002 | valid on 'valid' subset:  59% 919/1563 [00:14<00:10, 61.31it/s]
# epoch 002 | valid on 'valid' subset:  59% 926/1563 [00:14<00:10, 61.25it/s]
# epoch 002 | valid on 'valid' subset:  60% 933/1563 [00:14<00:10, 61.33it/s]
# epoch 002 | valid on 'valid' subset:  60% 940/1563 [00:14<00:10, 61.38it/s]
# epoch 002 | valid on 'valid' subset:  61% 947/1563 [00:14<00:10, 61.26it/s]
# epoch 002 | valid on 'valid' subset:  61% 954/1563 [00:14<00:09, 61.16it/s]
# epoch 002 | valid on 'valid' subset:  61% 961/1563 [00:14<00:09, 61.02it/s]
# epoch 002 | valid on 'valid' subset:  62% 968/1563 [00:14<00:09, 60.62it/s]
# epoch 002 | valid on 'valid' subset:  62% 975/1563 [00:15<00:09, 61.77it/s]
# epoch 002 | valid on 'valid' subset:  63% 982/1563 [00:15<00:09, 63.15it/s]
# epoch 002 | valid on 'valid' subset:  63% 989/1563 [00:15<00:08, 63.93it/s]
# epoch 002 | valid on 'valid' subset:  64% 996/1563 [00:15<00:08, 64.64it/s]
# epoch 002 | valid on 'valid' subset:  64% 1003/1563 [00:15<00:08, 64.88it/s]
# epoch 002 | valid on 'valid' subset:  65% 1010/1563 [00:15<00:08, 64.88it/s]
# epoch 002 | valid on 'valid' subset:  65% 1017/1563 [00:15<00:08, 63.52it/s]
# epoch 002 | valid on 'valid' subset:  66% 1024/1563 [00:15<00:08, 62.45it/s]
# epoch 002 | valid on 'valid' subset:  66% 1031/1563 [00:15<00:08, 61.49it/s]
# epoch 002 | valid on 'valid' subset:  66% 1038/1563 [00:16<00:08, 61.18it/s]
# epoch 002 | valid on 'valid' subset:  67% 1045/1563 [00:16<00:08, 61.12it/s]
# epoch 002 | valid on 'valid' subset:  67% 1052/1563 [00:16<00:08, 61.38it/s]
# epoch 002 | valid on 'valid' subset:  68% 1059/1563 [00:16<00:08, 61.70it/s]
# epoch 002 | valid on 'valid' subset:  68% 1066/1563 [00:16<00:08, 61.80it/s]
# epoch 002 | valid on 'valid' subset:  69% 1073/1563 [00:16<00:07, 61.85it/s]
# epoch 002 | valid on 'valid' subset:  69% 1080/1563 [00:16<00:07, 61.91it/s]
# epoch 002 | valid on 'valid' subset:  70% 1087/1563 [00:16<00:07, 62.07it/s]
# epoch 002 | valid on 'valid' subset:  70% 1094/1563 [00:16<00:07, 61.10it/s]
# epoch 002 | valid on 'valid' subset:  70% 1101/1563 [00:17<00:07, 60.92it/s]
# epoch 002 | valid on 'valid' subset:  71% 1108/1563 [00:17<00:07, 60.99it/s]
# epoch 002 | valid on 'valid' subset:  71% 1115/1563 [00:17<00:07, 61.06it/s]
# epoch 002 | valid on 'valid' subset:  72% 1122/1563 [00:17<00:07, 61.53it/s]
# epoch 002 | valid on 'valid' subset:  72% 1129/1563 [00:17<00:06, 63.12it/s]
# epoch 002 | valid on 'valid' subset:  73% 1136/1563 [00:17<00:06, 64.27it/s]
# epoch 002 | valid on 'valid' subset:  73% 1143/1563 [00:17<00:06, 65.08it/s]
# epoch 002 | valid on 'valid' subset:  74% 1150/1563 [00:17<00:06, 65.72it/s]
# epoch 002 | valid on 'valid' subset:  74% 1157/1563 [00:17<00:06, 66.07it/s]
# epoch 002 | valid on 'valid' subset:  74% 1164/1563 [00:18<00:06, 65.30it/s]
# epoch 002 | valid on 'valid' subset:  75% 1171/1563 [00:18<00:05, 65.71it/s]
# epoch 002 | valid on 'valid' subset:  75% 1178/1563 [00:18<00:05, 65.75it/s]
# epoch 002 | valid on 'valid' subset:  76% 1185/1563 [00:18<00:05, 66.09it/s]
# epoch 002 | valid on 'valid' subset:  76% 1192/1563 [00:18<00:05, 66.22it/s]
# epoch 002 | valid on 'valid' subset:  77% 1199/1563 [00:18<00:05, 66.27it/s]
# epoch 002 | valid on 'valid' subset:  77% 1206/1563 [00:18<00:05, 66.28it/s]
# epoch 002 | valid on 'valid' subset:  78% 1213/1563 [00:18<00:05, 66.38it/s]
# epoch 002 | valid on 'valid' subset:  78% 1220/1563 [00:18<00:05, 66.46it/s]
# epoch 002 | valid on 'valid' subset:  79% 1227/1563 [00:19<00:05, 65.87it/s]
# epoch 002 | valid on 'valid' subset:  79% 1234/1563 [00:19<00:05, 65.54it/s]
# epoch 002 | valid on 'valid' subset:  79% 1241/1563 [00:19<00:04, 65.66it/s]
# epoch 002 | valid on 'valid' subset:  80% 1248/1563 [00:19<00:04, 65.85it/s]
# epoch 002 | valid on 'valid' subset:  80% 1255/1563 [00:19<00:04, 66.01it/s]
# epoch 002 | valid on 'valid' subset:  81% 1262/1563 [00:19<00:04, 66.30it/s]
# epoch 002 | valid on 'valid' subset:  81% 1269/1563 [00:19<00:04, 66.40it/s]
# ...
# epoch 010 | valid on 'valid' subset:  13% 211/1563 [00:03<00:20, 65.85it/s]
# epoch 010 | valid on 'valid' subset:  14% 218/1563 [00:03<00:20, 65.88it/s]
# epoch 010 | valid on 'valid' subset:  14% 225/1563 [00:03<00:20, 65.36it/s]
# epoch 010 | valid on 'valid' subset:  15% 232/1563 [00:03<00:20, 65.41it/s]
# epoch 010 | valid on 'valid' subset:  15% 239/1563 [00:03<00:20, 65.30it/s]
# epoch 010 | valid on 'valid' subset:  16% 246/1563 [00:03<00:19, 65.85it/s]
# epoch 010 | valid on 'valid' subset:  16% 253/1563 [00:03<00:19, 65.88it/s]
# epoch 010 | valid on 'valid' subset:  17% 260/1563 [00:04<00:19, 66.20it/s]
# epoch 010 | valid on 'valid' subset:  17% 267/1563 [00:04<00:19, 66.11it/s]
# epoch 010 | valid on 'valid' subset:  18% 274/1563 [00:04<00:19, 65.86it/s]
# epoch 010 | valid on 'valid' subset:  18% 281/1563 [00:04<00:19, 66.13it/s]
# epoch 010 | valid on 'valid' subset:  18% 288/1563 [00:04<00:19, 66.14it/s]
# epoch 010 | valid on 'valid' subset:  19% 295/1563 [00:04<00:19, 66.00it/s]
# epoch 010 | valid on 'valid' subset:  19% 302/1563 [00:04<00:18, 66.39it/s]
# epoch 010 | valid on 'valid' subset:  20% 309/1563 [00:04<00:19, 65.60it/s]
# epoch 010 | valid on 'valid' subset:  20% 316/1563 [00:04<00:18, 66.18it/s]
# epoch 010 | valid on 'valid' subset:  21% 323/1563 [00:05<00:18, 66.60it/s]
# epoch 010 | valid on 'valid' subset:  21% 330/1563 [00:05<00:18, 66.89it/s]
# epoch 010 | valid on 'valid' subset:  22% 337/1563 [00:05<00:18, 67.07it/s]
# epoch 010 | valid on 'valid' subset:  22% 344/1563 [00:05<00:18, 66.82it/s]
# epoch 010 | valid on 'valid' subset:  22% 351/1563 [00:05<00:18, 67.04it/s]
# epoch 010 | valid on 'valid' subset:  23% 358/1563 [00:05<00:17, 66.99it/s]
# epoch 010 | valid on 'valid' subset:  23% 365/1563 [00:05<00:17, 67.00it/s]
# epoch 010 | valid on 'valid' subset:  24% 372/1563 [00:05<00:17, 67.06it/s]
# epoch 010 | valid on 'valid' subset:  24% 379/1563 [00:05<00:17, 66.58it/s]
# epoch 010 | valid on 'valid' subset:  25% 386/1563 [00:05<00:17, 66.77it/s]
# epoch 010 | valid on 'valid' subset:  25% 393/1563 [00:06<00:17, 66.91it/s]
# epoch 010 | valid on 'valid' subset:  26% 400/1563 [00:06<00:17, 67.01it/s]
# epoch 010 | valid on 'valid' subset:  26% 407/1563 [00:06<00:17, 66.67it/s]
# epoch 010 | valid on 'valid' subset:  26% 414/1563 [00:06<00:17, 66.87it/s]
# epoch 010 | valid on 'valid' subset:  27% 421/1563 [00:06<00:17, 67.00it/s]
# epoch 010 | valid on 'valid' subset:  27% 428/1563 [00:06<00:16, 66.83it/s]
# epoch 010 | valid on 'valid' subset:  28% 435/1563 [00:06<00:16, 67.07it/s]
# epoch 010 | valid on 'valid' subset:  28% 442/1563 [00:06<00:16, 67.26it/s]
# epoch 010 | valid on 'valid' subset:  29% 449/1563 [00:06<00:16, 67.07it/s]
# epoch 010 | valid on 'valid' subset:  29% 456/1563 [00:07<00:16, 67.10it/s]
# epoch 010 | valid on 'valid' subset:  30% 463/1563 [00:07<00:16, 67.11it/s]
# epoch 010 | valid on 'valid' subset:  30% 470/1563 [00:07<00:16, 67.11it/s]
# epoch 010 | valid on 'valid' subset:  31% 477/1563 [00:07<00:16, 67.03it/s]
# epoch 010 | valid on 'valid' subset:  31% 484/1563 [00:07<00:16, 66.72it/s]
# epoch 010 | valid on 'valid' subset:  31% 491/1563 [00:07<00:16, 66.61it/s]
# epoch 010 | valid on 'valid' subset:  32% 498/1563 [00:07<00:15, 66.77it/s]
# epoch 010 | valid on 'valid' subset:  32% 505/1563 [00:07<00:15, 67.03it/s]
# epoch 010 | valid on 'valid' subset:  33% 512/1563 [00:07<00:15, 67.21it/s]
# epoch 010 | valid on 'valid' subset:  33% 519/1563 [00:07<00:15, 67.40it/s]
# epoch 010 | valid on 'valid' subset:  34% 526/1563 [00:08<00:15, 66.86it/s]
# epoch 010 | valid on 'valid' subset:  34% 533/1563 [00:08<00:15, 66.17it/s]
# epoch 010 | valid on 'valid' subset:  35% 540/1563 [00:08<00:15, 65.77it/s]
# epoch 010 | valid on 'valid' subset:  35% 547/1563 [00:08<00:15, 65.73it/s]
# epoch 010 | valid on 'valid' subset:  35% 554/1563 [00:08<00:15, 65.74it/s]
# epoch 010 | valid on 'valid' subset:  36% 561/1563 [00:08<00:15, 65.57it/s]
# epoch 010 | valid on 'valid' subset:  36% 568/1563 [00:08<00:15, 65.63it/s]
# epoch 010 | valid on 'valid' subset:  37% 575/1563 [00:08<00:15, 65.82it/s]
# epoch 010 | valid on 'valid' subset:  37% 582/1563 [00:08<00:15, 65.32it/s]
# epoch 010 | valid on 'valid' subset:  38% 589/1563 [00:09<00:14, 65.47it/s]
# epoch 010 | valid on 'valid' subset:  38% 596/1563 [00:09<00:14, 65.50it/s]
# epoch 010 | valid on 'valid' subset:  39% 603/1563 [00:09<00:14, 65.76it/s]
# epoch 010 | valid on 'valid' subset:  39% 610/1563 [00:09<00:14, 65.64it/s]
# epoch 010 | valid on 'valid' subset:  39% 617/1563 [00:09<00:14, 65.33it/s]
# epoch 010 | valid on 'valid' subset:  40% 624/1563 [00:09<00:14, 65.23it/s]
# epoch 010 | valid on 'valid' subset:  40% 631/1563 [00:09<00:14, 65.20it/s]
# epoch 010 | valid on 'valid' subset:  41% 638/1563 [00:09<00:14, 65.06it/s]
# epoch 010 | valid on 'valid' subset:  41% 645/1563 [00:09<00:14, 65.08it/s]
# epoch 010 | valid on 'valid' subset:  42% 652/1563 [00:09<00:14, 65.03it/s]
# epoch 010 | valid on 'valid' subset:  42% 659/1563 [00:10<00:13, 65.30it/s]
# epoch 010 | valid on 'valid' subset:  43% 666/1563 [00:10<00:13, 65.41it/s]
# epoch 010 | valid on 'valid' subset:  43% 673/1563 [00:10<00:13, 65.55it/s]
# epoch 010 | valid on 'valid' subset:  44% 680/1563 [00:10<00:13, 65.51it/s]
# epoch 010 | valid on 'valid' subset:  44% 687/1563 [00:10<00:13, 65.57it/s]
# epoch 010 | valid on 'valid' subset:  44% 694/1563 [00:10<00:13, 65.63it/s]
# epoch 010 | valid on 'valid' subset:  45% 701/1563 [00:10<00:13, 65.73it/s]
# epoch 010 | valid on 'valid' subset:  45% 708/1563 [00:10<00:13, 65.53it/s]
# epoch 010 | valid on 'valid' subset:  46% 715/1563 [00:10<00:12, 65.61it/s]
# epoch 010 | valid on 'valid' subset:  46% 722/1563 [00:11<00:12, 65.22it/s]
# epoch 010 | valid on 'valid' subset:  47% 729/1563 [00:11<00:12, 65.23it/s]
# epoch 010 | valid on 'valid' subset:  47% 736/1563 [00:11<00:12, 65.33it/s]
# epoch 010 | valid on 'valid' subset:  48% 743/1563 [00:11<00:12, 65.34it/s]
# epoch 010 | valid on 'valid' subset:  48% 750/1563 [00:11<00:12, 65.11it/s]
# epoch 010 | valid on 'valid' subset:  48% 757/1563 [00:11<00:12, 64.49it/s]
# epoch 010 | valid on 'valid' subset:  49% 764/1563 [00:11<00:12, 64.59it/s]
# epoch 010 | valid on 'valid' subset:  49% 771/1563 [00:11<00:12, 65.01it/s]
# epoch 010 | valid on 'valid' subset:  50% 778/1563 [00:11<00:12, 65.40it/s]
# epoch 010 | valid on 'valid' subset:  50% 785/1563 [00:12<00:12, 63.94it/s]
# epoch 010 | valid on 'valid' subset:  51% 792/1563 [00:12<00:11, 64.67it/s]
# epoch 010 | valid on 'valid' subset:  51% 799/1563 [00:12<00:11, 65.16it/s]
# epoch 010 | valid on 'valid' subset:  52% 806/1563 [00:12<00:11, 65.47it/s]
# epoch 010 | valid on 'valid' subset:  52% 813/1563 [00:12<00:11, 65.41it/s]
# epoch 010 | valid on 'valid' subset:  52% 820/1563 [00:12<00:11, 65.38it/s]
# epoch 010 | valid on 'valid' subset:  53% 827/1563 [00:12<00:11, 64.99it/s]
# epoch 010 | valid on 'valid' subset:  53% 834/1563 [00:12<00:11, 64.05it/s]
# epoch 010 | valid on 'valid' subset:  54% 841/1563 [00:12<00:11, 64.22it/s]
# epoch 010 | valid on 'valid' subset:  54% 848/1563 [00:13<00:11, 64.30it/s]
# epoch 010 | valid on 'valid' subset:  55% 855/1563 [00:13<00:10, 64.69it/s]
# epoch 010 | valid on 'valid' subset:  55% 862/1563 [00:13<00:10, 65.09it/s]
# epoch 010 | valid on 'valid' subset:  56% 869/1563 [00:13<00:10, 65.15it/s]
# epoch 010 | valid on 'valid' subset:  56% 876/1563 [00:13<00:10, 65.06it/s]
# epoch 010 | valid on 'valid' subset:  56% 883/1563 [00:13<00:10, 65.59it/s]
# epoch 010 | valid on 'valid' subset:  57% 890/1563 [00:13<00:10, 66.03it/s]
# epoch 010 | valid on 'valid' subset:  57% 897/1563 [00:13<00:10, 65.69it/s]
# epoch 010 | valid on 'valid' subset:  58% 904/1563 [00:13<00:10, 64.31it/s]
# epoch 010 | valid on 'valid' subset:  58% 911/1563 [00:13<00:10, 64.79it/s]
# epoch 010 | valid on 'valid' subset:  59% 918/1563 [00:14<00:10, 64.14it/s]
# epoch 010 | valid on 'valid' subset:  59% 925/1563 [00:14<00:09, 64.76it/s]
# epoch 010 | valid on 'valid' subset:  60% 932/1563 [00:14<00:09, 64.49it/s]
# epoch 010 | valid on 'valid' subset:  60% 939/1563 [00:14<00:09, 64.22it/s]
# epoch 010 | valid on 'valid' subset:  61% 946/1563 [00:14<00:09, 64.11it/s]
# epoch 010 | valid on 'valid' subset:  61% 953/1563 [00:14<00:09, 63.79it/s]
# epoch 010 | valid on 'valid' subset:  61% 960/1563 [00:14<00:09, 63.20it/s]
# epoch 010 | valid on 'valid' subset:  62% 967/1563 [00:14<00:09, 62.93it/s]
# epoch 010 | valid on 'valid' subset:  62% 974/1563 [00:14<00:09, 64.25it/s]
# epoch 010 | valid on 'valid' subset:  63% 981/1563 [00:15<00:09, 63.45it/s]
# epoch 010 | valid on 'valid' subset:  63% 988/1563 [00:15<00:08, 64.39it/s]
# epoch 010 | valid on 'valid' subset:  64% 995/1563 [00:15<00:08, 65.14it/s]
# epoch 010 | valid on 'valid' subset:  64% 1002/1563 [00:15<00:08, 65.57it/s]
# epoch 010 | valid on 'valid' subset:  65% 1009/1563 [00:15<00:08, 65.85it/s]
# epoch 010 | valid on 'valid' subset:  65% 1016/1563 [00:15<00:08, 66.25it/s]
# epoch 010 | valid on 'valid' subset:  65% 1023/1563 [00:15<00:08, 66.30it/s]
# epoch 010 | valid on 'valid' subset:  66% 1030/1563 [00:15<00:07, 66.65it/s]
# epoch 010 | valid on 'valid' subset:  66% 1037/1563 [00:15<00:07, 66.90it/s]
# epoch 010 | valid on 'valid' subset:  67% 1044/1563 [00:16<00:07, 66.87it/s]
# epoch 010 | valid on 'valid' subset:  67% 1051/1563 [00:16<00:07, 66.93it/s]
# epoch 010 | valid on 'valid' subset:  68% 1058/1563 [00:16<00:07, 67.04it/s]
# epoch 010 | valid on 'valid' subset:  68% 1065/1563 [00:16<00:07, 66.74it/s]
# epoch 010 | valid on 'valid' subset:  69% 1072/1563 [00:16<00:07, 66.76it/s]
# epoch 010 | valid on 'valid' subset:  69% 1079/1563 [00:16<00:07, 66.81it/s]
# epoch 010 | valid on 'valid' subset:  69% 1086/1563 [00:16<00:07, 66.60it/s]
# epoch 010 | valid on 'valid' subset:  70% 1093/1563 [00:16<00:07, 66.88it/s]
# epoch 010 | valid on 'valid' subset:  70% 1100/1563 [00:16<00:06, 67.01it/s]
# epoch 010 | valid on 'valid' subset:  71% 1107/1563 [00:16<00:06, 66.72it/s]
# epoch 010 | valid on 'valid' subset:  71% 1114/1563 [00:17<00:06, 66.76it/s]
# epoch 010 | valid on 'valid' subset:  72% 1121/1563 [00:17<00:06, 66.63it/s]
# epoch 010 | valid on 'valid' subset:  72% 1128/1563 [00:17<00:06, 66.68it/s]
# epoch 010 | valid on 'valid' subset:  73% 1135/1563 [00:17<00:06, 66.83it/s]
# epoch 010 | valid on 'valid' subset:  73% 1142/1563 [00:17<00:06, 66.81it/s]
# epoch 010 | valid on 'valid' subset:  74% 1149/1563 [00:17<00:06, 66.58it/s]
# epoch 010 | valid on 'valid' subset:  74% 1156/1563 [00:17<00:06, 66.39it/s]
# epoch 010 | valid on 'valid' subset:  74% 1163/1563 [00:17<00:06, 66.53it/s]
# epoch 010 | valid on 'valid' subset:  75% 1170/1563 [00:17<00:05, 66.71it/s]
# epoch 010 | valid on 'valid' subset:  75% 1177/1563 [00:18<00:05, 66.53it/s]
# epoch 010 | valid on 'valid' subset:  76% 1184/1563 [00:18<00:05, 66.70it/s]
# epoch 010 | valid on 'valid' subset:  76% 1191/1563 [00:18<00:05, 65.79it/s]
# epoch 010 | valid on 'valid' subset:  77% 1198/1563 [00:18<00:05, 65.86it/s]
# epoch 010 | valid on 'valid' subset:  77% 1205/1563 [00:18<00:05, 66.07it/s]
# epoch 010 | valid on 'valid' subset:  78% 1212/1563 [00:18<00:05, 66.26it/s]
# epoch 010 | valid on 'valid' subset:  78% 1219/1563 [00:18<00:05, 65.95it/s]
# epoch 010 | valid on 'valid' subset:  78% 1226/1563 [00:18<00:05, 65.59it/s]
# epoch 010 | valid on 'valid' subset:  79% 1233/1563 [00:18<00:05, 65.90it/s]
# epoch 010 | valid on 'valid' subset:  79% 1240/1563 [00:18<00:04, 65.95it/s]
# epoch 010 | valid on 'valid' subset:  80% 1247/1563 [00:19<00:04, 66.03it/s]
# epoch 010 | valid on 'valid' subset:  80% 1254/1563 [00:19<00:04, 66.17it/s]
# epoch 010 | valid on 'valid' subset:  81% 1261/1563 [00:19<00:04, 66.26it/s]
# epoch 010 | valid on 'valid' subset:  81% 1268/1563 [00:19<00:04, 66.14it/s]
# epoch 010 | valid on 'valid' subset:  82% 1275/1563 [00:19<00:04, 66.27it/s]
# epoch 010 | valid on 'valid' subset:  82% 1282/1563 [00:19<00:04, 66.45it/s]
# epoch 010 | valid on 'valid' subset:  82% 1289/1563 [00:19<00:04, 66.65it/s]
# epoch 010 | valid on 'valid' subset:  83% 1296/1563 [00:19<00:04, 66.57it/s]
# epoch 010 | valid on 'valid' subset:  83% 1303/1563 [00:19<00:03, 66.45it/s]
# epoch 010 | valid on 'valid' subset:  84% 1310/1563 [00:20<00:03, 66.59it/s]
# epoch 010 | valid on 'valid' subset:  84% 1317/1563 [00:20<00:03, 66.24it/s]
# epoch 010 | valid on 'valid' subset:  85% 1324/1563 [00:20<00:03, 65.58it/s]
# epoch 010 | valid on 'valid' subset:  85% 1331/1563 [00:20<00:03, 65.07it/s]
# epoch 010 | valid on 'valid' subset:  86% 1338/1563 [00:20<00:03, 63.89it/s]
# epoch 010 | valid on 'valid' subset:  86% 1345/1563 [00:20<00:03, 64.37it/s]
# epoch 010 | valid on 'valid' subset:  87% 1352/1563 [00:20<00:03, 64.88it/s]
# epoch 010 | valid on 'valid' subset:  87% 1359/1563 [00:20<00:03, 65.14it/s]
# epoch 010 | valid on 'valid' subset:  87% 1366/1563 [00:20<00:03, 65.41it/s]
# epoch 010 | valid on 'valid' subset:  88% 1373/1563 [00:20<00:02, 65.38it/s]
# epoch 010 | valid on 'valid' subset:  88% 1380/1563 [00:21<00:02, 65.47it/s]
# epoch 010 | valid on 'valid' subset:  89% 1387/1563 [00:21<00:02, 63.85it/s]
# epoch 010 | valid on 'valid' subset:  89% 1394/1563 [00:21<00:02, 64.69it/s]
# epoch 010 | valid on 'valid' subset:  90% 1401/1563 [00:21<00:02, 65.35it/s]
# epoch 010 | valid on 'valid' subset:  90% 1408/1563 [00:21<00:02, 65.80it/s]
# epoch 010 | valid on 'valid' subset:  91% 1415/1563 [00:21<00:02, 65.56it/s]
# epoch 010 | valid on 'valid' subset:  91% 1422/1563 [00:21<00:02, 65.68it/s]
# epoch 010 | valid on 'valid' subset:  91% 1429/1563 [00:21<00:02, 65.55it/s]
# epoch 010 | valid on 'valid' subset:  92% 1436/1563 [00:21<00:01, 65.53it/s]
# epoch 010 | valid on 'valid' subset:  92% 1443/1563 [00:22<00:01, 65.47it/s]
# epoch 010 | valid on 'valid' subset:  93% 1450/1563 [00:22<00:01, 65.38it/s]
# epoch 010 | valid on 'valid' subset:  93% 1457/1563 [00:22<00:01, 65.01it/s]
# epoch 010 | valid on 'valid' subset:  94% 1464/1563 [00:22<00:01, 65.30it/s]
# epoch 010 | valid on 'valid' subset:  94% 1471/1563 [00:22<00:01, 65.35it/s]
# epoch 010 | valid on 'valid' subset:  95% 1478/1563 [00:22<00:01, 65.16it/s]
# epoch 010 | valid on 'valid' subset:  95% 1485/1563 [00:22<00:01, 65.38it/s]
# epoch 010 | valid on 'valid' subset:  95% 1492/1563 [00:22<00:01, 65.63it/s]
# epoch 010 | valid on 'valid' subset:  96% 1499/1563 [00:22<00:00, 65.54it/s]
# epoch 010 | valid on 'valid' subset:  96% 1506/1563 [00:23<00:00, 65.48it/s]
# epoch 010 | valid on 'valid' subset:  97% 1513/1563 [00:23<00:00, 65.44it/s]
# epoch 010 | valid on 'valid' subset:  97% 1520/1563 [00:23<00:00, 65.50it/s]
# epoch 010 | valid on 'valid' subset:  98% 1527/1563 [00:23<00:00, 65.64it/s]
# epoch 010 | valid on 'valid' subset:  98% 1534/1563 [00:23<00:00, 65.73it/s]
# epoch 010 | valid on 'valid' subset:  99% 1541/1563 [00:23<00:00, 65.88it/s]
# epoch 010 | valid on 'valid' subset:  99% 1548/1563 [00:23<00:00, 65.59it/s]
# epoch 010 | valid on 'valid' subset: 100% 1556/1563 [00:23<00:00, 67.61it/s]
#                                                                             2024-05-06 12:13:01 | INFO | valid | epoch 010 | valid on 'valid' subset | loss 0.716 | nll_loss 0.088 | accuracy 77.4 | wps 8507.2 | wpb 129.6 | bsz 16 | num_updates 3889 | best_accuracy 77.4
# 2024-05-06 12:13:01 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 10 @ 3889 updates
# 2024-05-06 12:13:01 | INFO | fairseq.trainer | Saving checkpoint to /content/fairseq/checkpoints/checkpoint10.pt
# 2024-05-06 12:13:09 | INFO | fairseq.trainer | Finished saving checkpoint to /content/fairseq/checkpoints/checkpoint10.pt
# 2024-05-06 12:13:32 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint10.pt (epoch 10 @ 3889 updates, score 77.4) (writing took 30.78978294699982 seconds)
# 2024-05-06 12:13:32 | INFO | fairseq_cli.train | end of epoch 10 (average epoch stats below)
# 2024-05-06 12:13:32 | INFO | train | epoch 010 | loss 0.447 | nll_loss 0.055 | accuracy 86.9 | wps 1279.1 | ups 2.47 | wpb 517.4 | bsz 63.9 | num_updates 3889 | lr 5.3425e-06 | gnorm 21.88 | loss_scale 128 | train_wall 102 | gb_free 17.5 | wall 1581
# 2024-05-06 12:13:32 | INFO | fairseq_cli.train | done training in 1580.5 seconds

# %%
import torch
import pickle

# Load the model from the .pt file
loaded_model = torch.load('your_model.pt')

# Save the loaded model as a pickle file
with open('your_model.pkl', 'wb') as f:
    pickle.dump(loaded_model, f)

# Load the model from the pickle file
with open('your_model.pkl', 'rb') as f:
    loaded_model_from_pickle = pickle.load(f)
